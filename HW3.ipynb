# %% [markdown]
# Assignment 3

# %%
import pandas as pd
import matplotlib.pyplot as plt
craters = pd.read_csv("AstroStats_Robbins_Moon.csv", sep = ',')

# %%
len(craters)
LAT_CIRC_IMG = craters["LON_CIRC_IMG"]
fig, ax = plt.subplots(figsize = (10, 10))
ax.hist(LAT_CIRC_IMG, bins=10)
plt.show()
