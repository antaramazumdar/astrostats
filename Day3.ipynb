# %%
import matplotlib.pyplot as plt
import numpy as np

theta = [0, 60, 120, 180, 240, 300]
values1 = [[187, 187, 187, 192], [132, 88, 55, 88], [132, 132, 121, 88], [187, 187, 187, 176], [66, 99, 99, 60], [132, 121, 121, 88]]
values2 = [[300, 228, 266, 266], [156, 156, 196, 195], [140, 75, 132, 136], [240, 280, 300, 266], [180, 150, 156, 196], [84, 255, 182, 154]]
o2 = [[300, 156, 140, 240, ]]

# %%
plt.figure() 
plt.ylabel("Brightness (squares)") 
plt.xlabel("Angle of rotation (degrees)") 

plt.xticks(theta)

plt.errorbar(theta[0], np.mean(values1[0]), yerr=np.std(values1[0]),fmt='--o', capsize = 5, color='blue')
plt.errorbar(theta[1], np.mean(values1[1]), yerr=np.std(values1[1]),fmt='--o',capsize = 5, color='blue')
plt.errorbar(theta[2], np.mean(values1[2]), yerr=np.std(values1[2]),fmt='--o',capsize = 5, color='blue')
plt.errorbar(theta[3], np.mean(values1[3]), yerr=np.std(values1[3]),fmt='--o',capsize = 5, color='blue')
plt.errorbar(theta[4], np.mean(values1[4]), yerr=np.std(values1[4]),fmt='--o',capsize = 5, color='blue')
plt.errorbar(theta[5], np.mean(values1[5]), yerr=np.std(values1[5]),fmt='--o',capsize = 5, color='blue')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.figure() 
plt.title("Lightcurve for Asteroid 'Do Not Disturb': Orientation B")
plt.ylabel("Brightness (squares)") 
plt.xlabel("Angle of rotation (degrees)") 
plt.xticks(theta)

plt.errorbar(theta[0], np.mean(values2[0]), yerr=np.std(values2[0]),fmt='--o',capsize = 5, color='blue')
plt.errorbar(theta[1], np.mean(values2[1]), yerr=np.std(values2[1]),fmt='--o',capsize = 5, color='blue')
plt.errorbar(theta[2], np.mean(values2[2]), yerr=np.std(values2[2]),fmt='--o',capsize = 5, color='blue')
plt.errorbar(theta[3], np.mean(values2[3]), yerr=np.std(values2[3]),fmt='--o',capsize = 5, color='blue')
plt.errorbar(theta[4], np.mean(values2[4]), yerr=np.std(values2[4]),fmt='--o',capsize = 5, color='blue')
plt.errorbar(theta[5], np.mean(values2[5]), yerr=np.std(values2[5]),fmt='--o',capsize = 5, color='blue')
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# 10. Can you draw a rough picture of the other group’s object? Do you
# know how it was oriented relative to the screen? Can you guess
# what it was? Explain the uncertainties in your answer. Then, if
# possible, check with the other group to see how accurate your
# answer was.
# From the second orientation set of data, the number of boxes covered does not seem to vary over time. This tells me that it is a symmetrical object being rotated about an axis along which it is uniformly symmetrical.
#
# 11. Do you think you could determine a rotation period from the
# lightcurve? That is, does the lightcurve have a distinctive pattern
# that repeats on each rotation?
# Yes, for the first orientation, the lightcurve does have a distinctive pattern that can be used to meassure the rotation period. However, if we only had the second rotation, it would have been impossible since it does not vary with time.
#
# 12. All the asteroids were slightly different in shape and size. What el-
# ements of your asteroids’ shapes and sizes made their lightcurves
# easier or harder to interpret?
# For my group's asteroid, iun one of the orientations, it was clear that one of the edges was a multiple of 11 because all our brightness levels were in multiples of 11. From the other group's asteroid, I could tell that it was much much smaller than our object because it different by an order of magnitude of 10. The second orientation also gave us the clue about being completely uniform about one axis which means that is probably cylindrical.
