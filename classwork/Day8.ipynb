# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("variable_stars.csv")

# %%
plt.figure()
plt.figure(figsize=(10, 6))
plt.scatter(data["P_1"], data["dP_1"])
plt.xlabel("P_1")
plt.ylabel("dP_1")
plt.show()
